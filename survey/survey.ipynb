# %% [markdown]
# <a href="https://colab.research.google.com/github/dcpetty/google-colaboratory/blob/main/survey/survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `survey.ipynb`
#
# Convert [SmartCat](https://smartcat.com/) `*.txt` files w/ two column to `*-translated.csv` files w/ three columns as follows:
# - Read `*-EN.csv` three-column file (last column blank) where the first column heading is `'PhraseID'`. (Remove leading `'\ufeff'` prefix character from `'PhraseID'` header &mdash; it appears to have been in the `.csv` file downloaded from [Qualtrics](https://www.qualtrics.com/).)
# - Read `*.txt` tab-delimited [UTF-16](https://en.wikipedia.org/wiki/UTF-16) binary file(s) downloaded from [https://smartcat.com/](https://smartcat.com/) as follows:
#   - Map `'PhraseID'` (equivalent) column value as the key and `'EN'` (equivalent) column value as the value. Column headings vary with each language.
#   - Assume all `'PhraseID'` (equivalent) values exist in both files.
# - Combine `'PhraseID'`, `'EN'`, and [strip](https://docs.python.org/3.4/library/stdtypes.html#str.strip)ped translation columns matching `'PhraseID'` key or translation.
#   - Keys *match* if the English key itself, or a translation of the English key, is in the translated file.
#   - Leave blank any translations w/o text.
# - Write out the new `.csv` file(s).
#
# ## Assumptions and hardwired values
#
# This [notebook](https://jupyter.org/) was setup for specific English, Portuguese, Spanish, Amharic, Arabic, Bengali, and Haitian Creole data files. Many of the values have been hardwired into the code and must be updated if anything changes with the survey and its translations or if other translations are to be added.
#
# - The `*-EN.csv` English source files and all the `*-translated.csv` result files default to [UTF-8 BOM](https://en.wikipedia.org/wiki/UTF-8#Byte-order_mark) encoding in the code.
# - The `*.txt` translated source files default to [UTF-16](https://en.wikipedia.org/wiki/UTF-16) encoding in the code.
# - The `directory` and pathnames for `path_EN_C`, `path_ES_C`, `path_PT_C`, `path_AM`, `path_AR`, `path_BN`, `path_ES` and `path_HT` are in the code.
# - The translated language column headings `'PT-BR'`, `'AM'`, `'AR'`, `'BN'`, `'ES'`, and `'HT'` are in the code.
# - The `'PhraseID'` substitution values (and the equivalent headers) are in the code:
# ```python
#     replacements = (
#         ('Resposta', 'Answer', ),                                               # Português
#         ('opción', 'Choice', ), ('Elección', 'Choice', ), ('Nivel', 'Level', ), # Español
#         ('Chwa', 'Choice'),                                                     # Kreyòl ayisyen
#     )
# ```
# - The Boolean variables `check_for_extra_spaces` and `check_for_missing_keys` for debugging are in the code and initialized to `False`.
#
# ## TODO:
#
# - Check `*.txt` files for duplicate keys (masked by [`DictReader`](https://docs.python.org/3/library/csv.html#csv.DictReader))
# - Replace all `'\u00a0'` characters & `'&nbsp;'` (HTML entity `'&nbsp;'`) with `' '`. **Note:** The presense of `'\u00a0'` originally caused file-loading issues.

# %%
#!/usr/bin/env python3
#
# convert.py
#
# Convert SmartCat *.txt files w/ two column to *-translated.csv files w/ three columns as follows:
# - Read *-EN.csv three-column file (last column blank) where the first column heading is 'PhraseID'.
#   (Remove leading '\ufeff' prefix character from 'PhraseID' header.)
# - Read *.txt tab-delimited UTF-16 binary file(s) downloaded from https://smartcat.com/ as follows:
#   - Map 'PhraseID' (equivalent) column value as the key and 'EN' (equivalent) column value as the
#     value. Column headings vary with each language.
#   - Assume all 'PhraseID' (equivalent) values exist in both files.
# - Combine 'PhraseID', 'EN', and stripped translation columns matching 'PhraseID' key or translation.
#   - Keys 'match' if the English key, or a translation of the English key, is in the translated file.
#   - Use the English for any translations w/o text.
#   - Strip any urldefense patterns to leave the raw href / src.
# - Write out the new .csv file(s) with 'utf-8-sig' encoding.
#
# TODO:
# - Check *.txt files for duplicate keys (masked by DictReader)
# - Replace all '\u00a0' characters & '&nbsp;' (HTML entity '&nbsp;') w/ ' '.
#

import csv, os.path, re

# From https://github.io/dcpetty/google-colaboratory/remote-files
from os.path import join, realpath
dot_path = realpath('.')
gdrive = join(dot_path, 'gdrive')
notebooks = join(gdrive, 'My Drive/Colab Notebooks')
repo = 'survey' # repo path within the Drive/Colab Notebooks directory
drive_path = join(notebooks, repo)

from google.colab import drive
drive.mount(gdrive)

directory = join(drive_path, 'data')

# Conjoint version.
path_EN_C = os.path.join(directory, 'Cambridge PD Conjoint-EN.csv')
path_PT_C = os.path.join(directory, 'Cambridge PD Conjoint-EN-PT(pt-BR).txt')
path_ES_C = os.path.join(directory, 'Cambridge PD Conjoint-EN-ES-ES(es-US).txt')

# Infant / Toddler version.
path_EN = os.path.join(directory, 'Cambridge Infant Toddler Family Survey-EN.csv')
path_AM = os.path.join(directory, 'Cambridge Infant Toddler Family Survey-EN-AM.txt')
path_AR = os.path.join(directory, 'Cambridge Infant Toddler Famliy Survey-EN-AR.txt')
path_BN = os.path.join(directory, 'Cambridge Infant Toddler Family Survey-EN-BN.txt')
path_ES = os.path.join(directory, 'Cambridge Infant Toddler Family Survey-EN-ES.txt')
path_HT = os.path.join(directory, 'Cambridge Infant Toddler Family Survey-EN-HT.txt')

# Conjoint dictionaries from files.
with open(path_EN_C, 'r') as f1, \
    open(path_PT_C, 'r', encoding='utf16') as f2, \
    open(path_ES_C, 'r', encoding='utf16') as f3:
    reader_EN_C = csv.reader(f1)
    # TODO: check these for duplicate keys (masked by DictReader)
    reader_ES_C = csv.DictReader(f3, delimiter='\t')
    reader_PT_C = csv.DictReader(f2, delimiter='\t')
    # english = [ [ cell.strip() for cell in row ] for row in reader_EN_C ]
    # TODO: do *not* strip() the English input for the EN column (though, probably OK)
    english_conjoint = [ row for row in reader_EN_C ]
    portuguese_conjoint = { row['ID da frase']: row['IN'] for row in reader_PT_C }
    spanish_conjoint = { row['PhraseID']: row['EN'] for row in reader_ES_C }

# Infant / Toddler dictionaries from files.
with open(path_EN, 'r', newline='') as f4, \
    open(path_AM, 'r', encoding='utf16', newline='') as f5, \
    open(path_AR, 'r', encoding='utf16', newline='') as f6, \
    open(path_BN, 'r', encoding='utf16', newline='') as f7, \
    open(path_ES, 'r', encoding='utf16', newline='') as f8, \
    open(path_HT, 'r', encoding='utf16', newline='') as f9:
    reader_EN = csv.reader(f4)
    # TODO: check these for duplicate keys (masked by DictReader)
    reader_AM = csv.DictReader(f5, delimiter='\t')
    reader_AR = csv.DictReader(f6, delimiter='\t')
    reader_BN = csv.DictReader(f7, delimiter='\t')
    reader_ES = csv.DictReader(f8, delimiter='\t')
    reader_HT = csv.DictReader(f9, delimiter='\t')
    # english = [ [ cell.strip() for cell in row ] for row in reader_EN ]
    # TODO: do *not* strip() the English input for the EN column (though, probably OK)
    english = [ row for row in reader_EN ]
    spanish = { row['PhraseID']: row['EN'] for row in reader_ES }
    amharic = { row['PhraseID']: row['EN'] for row in reader_AM }
    arabic = { row['PhraseID']: row['EN'] for row in reader_AR }
    bengali = { row['PhraseID']: row['EN'] for row in reader_BN }
    creole = { row['PhraseID']: row['EN'] for row in reader_HT }

# Data checks.
check_for_extra_spaces = False
if check_for_extra_spaces:
    print('Check for extra spaces in text...')
    print('EN-C', [ f"'{text}'" for row in english_conjoint for text in row if text.strip() != text ])
    print('ES-C', [ f"'{text}'" for text in spanish_conjoint.values() if text.strip() != text ])
    print('PT-C', [ f"'{text}'" for text in portuguese_conjoint.values() if text.strip() != text ])
    print('EN  ', [ f"'{text}'" for row in english for text in row if text.strip() != text ])
    print('AM  ', [ f"'{text}'" for text in amharic.values() if text.strip() != text ])
    print('AR  ', [ f"'{text}'" for text in arabic.values() if text.strip() != text ])
    print('BN  ', [ f"'{text}'" for text in bengali.values() if text.strip() != text ])
    print('ES  ', [ f"'{text}'" for text in spanish.values() if text.strip() != text ])
    print('HT  ', [ f"'{text}'" for text in creole.values() if text.strip() != text ])
    print(f"'{spanish.get('CBConjoint_Feature6_Level1', '?')}'")
    print(f"'{spanish.get('QID75_Choice7', '?')}'")
check_for_missing_keys = False
if check_for_missing_keys:
    print('Check for missing keys in translation...')
    keys = { row[0] for row in english_conjoint }
    print('ES-C', [ key for key in spanish_conjoint if key not in keys ])
    print('PT-C', [ key for key in portuguese_conjoint if key not in keys ])
    keys = { row[0] for row in english }
    print('AM', [ key for key in amharic if key not in keys ])
    print('AR', [ key for key in arabic if key not in keys ])
    print('BN', [ key for key in bengali if key not in keys ])
    print('ES', [ key for key in spanish if key not in keys ])
    print('HT', [ key for key in creole if key not in keys ])

def value(translations, key, default=''):
    """Return translations[key] if it exists, otherwise translations[translated_key]
    if it exists, otherwise default. All returned values have urldefense removed."""
    replacements = (
        ('Resposta', 'Answer', ),                                               # Português
        ('opción', 'Choice', ), ('Elección', 'Choice', ), ('Nivel', 'Level', ), # Español
        ('Chwa', 'Choice'),                                                     # Kreyòl ayisyen
    )
    # urldefense pattern.
    pattern = r'(src|href)="https://urldefense\.com/v3/__(.*?)__;!!.*?"'
    ret = lambda text: re.sub(pattern, r'\1="\2"', text.strip())
    if key in translations:
        return ret(translations[key])
    for trans, eng in replacements:
        # TODO: deal with multi-case keys
        translated_key = key.replace(eng, trans)
        if translated_key in translations:
            return ret(translations[translated_key])
    print(f"No key matches '{key}'")
    return ret(default)

# Perform all translations.
translations = [
    ('PT-BR', english_conjoint, portuguese_conjoint, path_PT_C, ),
    ('ES-ES', english_conjoint, spanish_conjoint, path_ES_C, ),
    ('AM', english, amharic, path_AM, ),
    ('AR', english, arabic, path_AR, ),
    ('BN', english, bengali, path_BN, ),
    ('ES', english, spanish, path_ES, ),
    ('HT', english, creole, path_HT, ),
]
for name, mapfrom, mapto, path in translations:
    # Combine English / Name – remove leading '\ufeff' from 0th row.
    combined = [ [ 'PhraseID', 'EN', name, ] ] + \
        [ [ row[0], row[1], value(mapto, row[0], row[1]), ] for row in mapfrom[1: ] ]

    # Write out translated .CSV.
    root, ext = os.path.splitext(path)
    path_out = f"{root}-translated.csv"
    print(f"Writing {path_out}...")
    with open(path_out, 'w', encoding='utf-8-sig', newline='') as fout:
        writer = csv.writer(fout, quoting=csv.QUOTE_ALL)
        writer.writerows(combined)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge PD Conjoint-EN-PT(pt-BR)-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge PD Conjoint-EN-ES-ES(es-US)-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge Infant Toddler Family Survey-EN-AM-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge Infant Toddler Famliy Survey-EN-AR-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge Infant Toddler Family Survey-EN-BN-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge Infant Toddler Family Survey-EN-ES-translated.csv...
# Writing /content/gdrive/My Drive/Colab Notebooks/survey/data/Cambridge Infant Toddler Family Survey-EN-HT-translated.csv...
